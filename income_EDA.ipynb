# %% [markdown]
# <a href="https://colab.research.google.com/github/abdallah155/EDA_Adult-Census-Income/blob/main/income_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = '/content/adult.csv'
df = pd.read_csv(url)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ## univariate analysis

# %%
df['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# *   most of the ages of people <= 45 years

# %%
df['income'].hist()
# Out:
# <Axes: >

# %% [markdown]
# *   most of the people takes less than 50k per year

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %% [markdown]
# *   most of the people are males

# %%
df['educational-num'].hist()
# Out:
# <Axes: >

# %% [markdown]
# *   most of the people got 9y of education

# %%
sns.countplot(df,x=df['race'])
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %% [markdown]
# *   most of the people are white in the dataset

# %%
sns.countplot(df,x=df['relationship'])
# Out:
# <Axes: xlabel='relationship', ylabel='count'>

# %% [markdown]
# *   a husband is the greatest count in the dataset

# %%
sns.countplot(df,y=df['native-country'])
# Out:
# <Axes: xlabel='count', ylabel='native-country'>

# %% [markdown]
# *   most of the people are from USA

# %%
sns.countplot(y=df['marital-status'])
# Out:
# <Axes: xlabel='count', ylabel='marital-status'>

# %% [markdown]
# *   most of the people are married to a civilan spouse

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# ###### we're interested in the target variable so the analysis is the relationship bet. variable and the target variable

# %%
sns.countplot(df,x=df['race'],hue=df['income'])
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %% [markdown]
# *   white people make more than 50k income than other races

# %%
sns.countplot(df,x=df['gender'],hue=df['income'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# *    males make more 50ks than females

# %%
sns.countplot(df,y=df['occupation'],hue=df['income'])
# Out:
# <Axes: xlabel='count', ylabel='occupation'>

# %% [markdown]
# *   Exec-managerial
# *   Prof-specialty
# *   sales
# *   Craft-repair
# *   these jobs makes >50k than other jobs ranked by order

# %%
sns.countplot(df,y=df['educational-num'],hue=df['income'])
# Out:
# <Axes: xlabel='count', ylabel='educational-num'>

# %% [markdown]
# * people got more than or equal 9y of edu makes >50k than the less years of edu.
# * people got more than 13y of edu makes >50ks than the <=50ks group

# %%
sns.countplot(df,y=df['education'],hue=df['income'])
# Out:
# <Axes: xlabel='count', ylabel='education'>

# %% [markdown]
# * doctorate and masters makes >50k than <=50k
# * but people whom have bachelors make >50k than the whole group

# %%
sns.countplot(df,y=df['workclass'],hue=df['income'])
# Out:
# <Axes: xlabel='count', ylabel='workclass'>

# %% [markdown]
# * private section making >50k than other sections

# %%
sns.countplot(df,y=df['marital-status'],hue=df['income'])
# Out:
# <Axes: xlabel='count', ylabel='marital-status'>

# %% [markdown]
# * people who are married makes >50k than other

# %%
sns.countplot(df,y=df['relationship'],hue=df['income'])
# Out:
# <Axes: xlabel='count', ylabel='relationship'>

# %% [markdown]
# * a husband makes >50k than others

# %%
sns.boxplot(x='income',y='age',data=df)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# * the median of people making <=50k 34years old, while the median of >50k is 44
# * greater than 75% of people whom make above 50k are less than 50 years old

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-51-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# * no any correlation between data and each other

# %% [markdown]
# ## multivariate analysis

# %%
sns.pairplot(df,hue='income')
